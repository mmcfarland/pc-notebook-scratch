# %%
import xarray as xr

# %%
ds = xr.open_dataset("data/Katrina_2005.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 1635, lon: 1981, time: 1)
# Coordinates:
#   * time        (time) datetime64[ns] 2010-01-01
#   * lat         (lat) float64 20.14 20.15 20.16 20.17 ... 35.25 35.26 35.27
#   * lon         (lon) float64 -94.38 -94.37 -94.36 ... -76.06 -76.05 -76.04
# Data variables:
#     projection  |S1 ...
#     inun        (time, lat, lon) float32 ...
# Attributes:
#     source:       Global Tide and Surge Model v3.0 - ERA5
#     institution:  Deltares
#     title:        Global Coastal Hazard Layer
#     references:   ''
#     Conventions:  CF-1.6
#     project:      PBL coastal flood maps
#     config_file:  /p/temp/01_events/NASADEM_1km_no_wm/Katrina_2005/eventTest_...
#     history:      Created by: $Id: coastal_inun.py 528 2018-06-19 08:41:05Z e...

# %%
ds.inun.plot(figsize=(10,8), cmap="Reds")

# %%
ds.inun.where(ds.inun > 0, drop=True).plot(figsize=(10,8), cmap="Reds")
